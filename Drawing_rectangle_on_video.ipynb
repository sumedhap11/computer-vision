# %%
import cv2
import numpy as np

# %%
import cv2
cap=cv2.VideoCapture(0)
#automatically grab width and height from video feed
width= int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height=int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
#coordinates for rectangle ,centre point rectangle
x=width//2
y=height//2
#width and height adding 1/4 of width and height from the centre
w=width//4
h=height//4

while True:
    ret,frame=cap.read()
    
    cv2.rectangle(frame, (x,y),(x+w,y+h),color=(0,0,255),thickness=4)
    cv2.imshow('frame',frame)
    
    if cv2.waitKey(1)& 0xFF==ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

# %%
import cv2

#global variables to store points
pt1=(0,0)             #first corner
pt2=(0,0)
topleft_clicked=False
botRight_clicked=False

def draw_rectangle(event,x,y,flags,param):
    global pt1,pt2,topleft_clicked,botRight_clicked
    #Detect left mouse button click
    if event == cv2.EVENT_LBUTTONDOWN:
        #case1=both corners were selected earlier-reset everything
        if topLeft_clicked and botRight_clicked:
            topLeft_clicked=False
            botRight_clicked=False
            pt1=(0,0)
            pt2=(0,0)
        #case2:first clicke - set top-left corner
        if not topLeft_clicked:
            pt1=(x,y)
            topLeft_clicked=True
        #case3: second click- set bottom-right corner
        elif not botRight_clicked:
            pt2=(x,y)
            botRight_clicked=True
cap=cv2.VideoCapture(0)
cv2.namedWindow('Test')
cv2.setMouseCallback('Test',draw_rectangle)

while True:
    ret,frame=cap.read()
    if topLeft_clicked:
        cv2.circle(frame,center=pt1,radius=5,color=(0,0,255),thickness=-1)
        
    if topLeft_clicked and botRight_clicked:
        cv2.rectangle(frame,pt1,pt2,(0,0,255),2)
    cv2.imshow('Test',frame)
    if cv2.waitKey(1) & 0xFF ==ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
