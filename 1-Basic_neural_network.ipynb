# %%
#simple neural network
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Flatten
from tensorflow.keras.datasets import mnist

# %%
#load the MNIST dataset (images of digits)
(x_train,y_train),(x_test,y_test)=mnist.load_data()
# images are 0-255 normalalize them to 0-1
x_train=x_train/255.0
x_test=x_test/255.0

# %%
model=Sequential([
    Flatten(input_shape=(28,28)),
    Dense(128,activation='relu'),
    Dense(10,activation='softmax')
])

# %%
model.compile( 
optimizer='adam',
loss='sparse_categorical_crossentropy',
metrics=['accuracy'])
'''
we choose
'''
# Out:
# '\nwe choose\n'

# %%
model.fit(x_train,y_train,epochs=5)
# Out:
# Epoch 1/5
# 60000/60000 [==============================] - 12s 201us/step - loss: 0.2492 - acc: 0.9290
# Epoch 2/5
# 60000/60000 [==============================] - 11s 176us/step - loss: 0.1082 - acc: 0.9680
# Epoch 3/5
# 60000/60000 [==============================] - 11s 180us/step - loss: 0.0747 - acc: 0.9770
# Epoch 4/5
# 60000/60000 [==============================] - 11s 182us/step - loss: 0.0557 - acc: 0.9828
# Epoch 5/5
# 60000/60000 [==============================] - 11s 180us/step - loss: 0.0444 - acc: 0.9859

# %%
test_loss, test_acc=model.evaluate(x_test,y_test)
print("Test Accuracy:",test_acc)
# Out:
# 10000/10000 [==============================] - 1s 75us/step
# Test Accuracy: 0.9769
