# %%
import numpy as np
import matplotlib.pyplot as plt

x=np.linspace(-10,10,400)

#Tan h function
def tanh_function(x):
    return np.tanh(x)
y=tanh_function(x)

#plot
plt.plot(x,y)
plt.title("Tanh Activation Function")
plt.xlabel("Input")
plt.ylabel("Output")
plt.grid(True)
plt.show()

print("\nTanh Advantages:")
print("1.Zero-centered output-> better training than sigmoid.")
print("2.Output between -1 and 1.")

print("\nTanh Disadvantages:")
print("1.still suffers from vanishing gradients.")
print("2.Saturates at large +ve or -ve x values.")
# Out:
# Tanh Advantages:
# 1.Zero-centered output-> better training than sigmoid.
# 2.Output between -1 and 1.
#
# Tanh Disadvantages:
# 1.still suffers from vanishing gradients.
# 2.Saturates at large +ve or -ve x values.
